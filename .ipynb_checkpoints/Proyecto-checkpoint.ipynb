# %% [markdown]
# # Faragó Facundo - Gustavo Doctorovich

# %% [markdown]
# # **Cargar repositorio**

# %% [markdown]
# # **Importar librerias y dataset**

# %%
# Librerías
import numpy as np
import matplotlib.pyplot as plt
from scipy.signal import detrend
import WholeBrain.Observables.FC as FC
import WholeBrain.Observables.swFCD as swFCD
import WholeBrain.Observables.phFCD as phFCD
import WholeBrain.Observables.GBC as GBC
import Tests.DecoEtAl2014.fig2 as fig_Deco
import Tests.DecoEtAl2014.fig2_optim as fig_Deco_optim
import Tests.HerzogEtAl2022.fig2 as fig_Herzog
import WholeBrain.Integrators.EulerMaruyama as EulerMaruyama
import os

fig_Deco.BalanceFIC.integrator = EulerMaruyama
fig_Deco_optim.BalanceFIC.integrator = EulerMaruyama
fig_Herzog.Herzog2022Mechanism.integrator= EulerMaruyama
fig_Deco.integrator.recompileSignatures()
# Cambio constante de la libreria para que no descarte datos
phFCD.discardOffset = 0

# Ruta al archivo de texto con los datos de los sujetos 25x25
ruta_archivo_25 = 'Datos/Datasets/netmats2_25.txt'

# Ruta al archivo de texto con los datos de los sujetos 200x200
ruta_archivo_200 = 'Datos/Datasets/netmats2_200.txt'

# Ruta al archivo de texto con los time series
ruta_archivo_ts = 'Datos/Datasets/100206.txt'

# Cargar los datos de los sujetos desde los archivos de texto
datos_sujetos_25 = np.loadtxt(ruta_archivo_25)
datos_sujetos_200 = np.loadtxt(ruta_archivo_200)

# Reshape para crear matriz 3D 
matrices_por_sujeto_25 = datos_sujetos_25.reshape((1003, 25, 25))
matrices_por_sujeto_200 = datos_sujetos_200.reshape((1003, 200, 200))

# Cargar los datos timeseries de los sujetos desde el archivo de texto
datos_ts = np.loadtxt(ruta_archivo_ts)

# Reshape para crear una matriz 2D (4800, 25)
matriz_ts = datos_ts.reshape((4800, 25))
matriz_tsT = matriz_ts.T
# Out:
# Going to use Functional Connectivity (FC)...
# Going to use Sliding Windows Functional Connectivity Dynamics (swFCD)...
# Going to use Phase-Interaction Matrix...
# Going to use Phase Functional Connectivity Dynamics (phFCD)...
# Going to use Global Brain Connectivity (GBC)...
# Going to use the Dynamic Mean Field (DMF) neuronal model...
# Going to use the Euler-Maruyama Integrator...
# Going to use the Balanced J9 (FIC) mechanism...
# Going to use the Balanced J9 (FIC) mechanism in DecoEtAl2014...
# Going to use the Balanced J (FIC) mechanism in HerzogEtAl2022...

# %% [markdown]
# # **Resultados**

# %% [markdown]
# ## Matriz de conectividad

# %%
# Seleccionar una sola matriz de conectividad (por ejemplo, la primera)
matriz_conectividad_individual = matrices_por_sujeto_25[0]

# Crear la visualización de la matriz de conectividad individual
plt.imshow(matriz_conectividad_individual, cmap='coolwarm', interpolation='none')
plt.colorbar()  # Añadir la barra de color
plt.title('Matriz de Conectividad del Primer Sujeto')
plt.xlabel('Regiones del Cerebro')
plt.ylabel('Regiones del Cerebro')

# Mostrar la visualización
plt.show()

# %% [markdown]
# ## Matriz promedio de matrices de conectividad

# %%
# Calcular la matriz de conectividad promedio de todos los sujetos
matriz_conectividad_promedio = np.mean(matrices_por_sujeto_25, axis=0)
matriz_conectividad_promedio = matriz_conectividad_promedio/matriz_conectividad_promedio.max()
matriz_conectividad_promedio = matriz_conectividad_promedio*0.1
# Visualizar la matriz de conectividad promedio
plt.imshow(matriz_conectividad_promedio, cmap='coolwarm', interpolation='none')
plt.colorbar()  # Añadir la barra de color
plt.title('Matriz de Conectividad Promedio de Todos los Sujetos')
plt.xlabel('Regiones del Cerebro')
plt.ylabel('Regiones del Cerebro')

# Mostrar la visualización
plt.show()

# %% [markdown]
# ## fRMI

# %%
# Calcular el promedio de cada columna
promedios = np.mean(matriz_ts, axis=0)

# Restar el promedio de cada columna a la misma columna
matrizrp = matriz_ts - promedios

matrizrp_detrended = detrend(matrizrp, type='linear')

# Crear un gráfico con un tamaño más grande
plt.figure(figsize=(12, 8))

# Obtener el número de columnas y generar colores únicos para cada una de las regiones
num_columnas = matrizrp_detrended.shape[1]
colores = plt.cm.coolwarm(np.linspace(0, 1, num_columnas))

# Iterar sobre cada columna de la matriz y graficarla como una curva con un color distinto cada región
for i in range(num_columnas):
    plt.plot(matrizrp_detrended[:, i], color=colores[i], label=f'Columna {i+1}')

# Agregar etiquetas y leyenda
plt.xlabel('Índice')
plt.ylabel('Valor')

# Ajustar el tamaño de la fuente
plt.rcParams['font.size'] = 12

# Rotar las etiquetas del eje x para evitar superposiciones
plt.xticks(rotation=45)

# Mejorar la disposición del gráfico
plt.tight_layout()

# Ajustar la posición de la leyenda fuera del área del gráfico
plt.legend(loc='upper left', bbox_to_anchor=(1, 1))

# Ajustar los márgenes del gráfico
plt.margins(x=0.1, y=0.1)

# Mostrar el gráfico
plt.show()

# %% [markdown]
# ## Correlacion (fMRI)

# %%
# Calcular el promedio de cada columna
promedios = np.mean(matriz_ts, axis=0)

# Restar el promedio de cada columna a la misma columna
matrizrp = matriz_ts - promedios

matrizrp_detrended = detrend(matrizrp, type='linear')

matriz_correlacion = np.corrcoef(matrizrp_detrended, rowvar=False)

# Crear la visualización de la matriz de correlación promedio
plt.imshow(matriz_correlacion, cmap='coolwarm', interpolation='none')
plt.colorbar()  # Añadir la barra de color
plt.title('Matriz de Correlación')
plt.xlabel('Regiones del Cerebro')
plt.ylabel('Regiones del Cerebro')


# Mostrar la visualización
plt.show()

# %% [markdown]
# ## Con WholeBrain

# %% [markdown]
# ### Functional Connectivity

# %%
FC_mt = FC.from_fMRI(matriz_tsT, True, True)

# Crear la visualización de la matriz de correlación promedio
plt.imshow(FC_mt, cmap='coolwarm')
plt.colorbar()  # Añadir la barra de color
plt.title('Functional Connectivity')
plt.xlabel('Regiones del Cerebro')
plt.ylabel('Regiones del Cerebro')

# Mostrar la visualización
plt.show()

# %% [markdown]
# ### Sliding Window FCD

# %%
sw_FCD = swFCD.from_fMRI(matriz_tsT,True,True)
sw_FCD_mt = swFCD.buildFullMatrix(sw_FCD)

# %%
# Ajustar el tamaño de la figura
plt.figure(figsize=(5, 5))  # Puedes ajustar los valores (ancho, alto) según tus preferencias

# Crear la visualización de la matriz de correlación promedio
plt.imshow(sw_FCD_mt, cmap='coolwarm')
plt.colorbar()  # Añadir la barra de color
plt.title('Sliding Window FCD')
plt.xlabel('Time')
plt.ylabel('Time')

# Mostrar la visualización
plt.show()

# %% [markdown]
# ### Phase Interaction Matrix

# %%
ph_FCD = phFCD.from_fMRI(matriz_tsT,True,True)
ph_FCD_mt = phFCD.buildFullMatrix(ph_FCD)

# %%
# Ajustar el tamaño de la figura
plt.figure(figsize=(5, 5))  # Puedes ajustar los valores (ancho, alto) según tus preferencias

# Crear la visualización de la matriz de correlación promedio
plt.imshow(ph_FCD_mt, cmap='coolwarm')
plt.colorbar()  # Añadir la barra de color
plt.title('Phase Interaction Matrix')
plt.xlabel('Time')
plt.ylabel('Time')

# Mostrar la visualización
plt.show()

# %% [markdown]
# ### Global Brain Connectivity

# %%
FCD_mt = GBC.from_fMRI(matriz_tsT,True,True)
GBC_mt = GBC.postprocess(FCD_mt)

# %%
# Reformatear el vector a una matriz de una columna (25x1)
matriz = GBC_mt.reshape((25, 1))

# Crear la figura y los ejes
fig, ax = plt.subplots()

# Mostrar la matriz como imagen
im = ax.imshow(matriz, cmap='coolwarm', aspect='auto', extent=[0, 1, 0, 25])

# Añadir una barra de color
cbar = plt.colorbar(im, ax=ax)
cbar.set_label('Valor')

# Ajustar las etiquetas del eje x
ax.set_xticks([])  # Desactivar las etiquetas del eje x

# Añadir etiquetas y título
plt.ylabel('Regiones del Cerebro')
plt.title('Global Brain Connectivity')

# Mostrar la visualización
plt.show()

# %% [markdown]
# ### Figura DMF

# %% [markdown]
# #### Deco

# %%
# Carpeta destino

folder_path = 'Datos/Results/Results_test2'

fig_Deco_optim.plotMaxFrecForAllWe(matriz_conectividad_promedio, fileName=os.path.join(folder_path, 'results_{}.txt'), num_processes= 4, wStart = 5)
# Out:
# ======================================
# =    simulating E-E (no FIC)         =
# ======================================
# 100%|██████████| 20/20 [00:15<00:00,  1.26it/s]
# ======================================
# =    simulating FIC                  =
# ======================================
# Computing (@loadOrCompute): Datos/Results/Results_test2\results_5.05.txt
# Balancing for we=5.05
# Computing (@loadOrCompute): Datos/Results/Results_test2\results_5.1.txt
# Balancing for we=5.1
# Computing (@loadOrCompute): Datos/Results/Results_test2\results_5.15.txt
# Balancing for we=5.1499999999999995
# Computing (@loadOrCompute): Datos/Results/Results_test2\results_5.2.txt
# Balancing for we=5.199999999999999
# Computing (@loadOrCompute): Datos/Results/Results_test2\results_5.25.txt
# Balancing for we=5.249999999999999
# Computing (@loadOrCompute): Datos/Results/Results_test2\results_5.3.txt
# Balancing for we=5.299999999999999
# Computing (@loadOrCompute): Datos/Results/Results_test2\results_5.35.txt
# Balancing for we=5.349999999999999
# Computing (@loadOrCompute): Datos/Results/Results_test2\results_5.4.txt
# Balancing for we=5.399999999999999
# Computing (@loadOrCompute): Datos/Results/Results_test2\results_5.45.txt
# Balancing for we=5.449999999999998
# Computing (@loadOrCompute): Datos/Results/Results_test2\results_5.5.txt
# Balancing for we=5.499999999999998
# Computing (@loadOrCompute): Datos/Results/Results_test2\results_5.55.txt
# Balancing for we=5.549999999999998
# Computing (@loadOrCompute): Datos/Results/Results_test2\results_5.6.txt
# Balancing for we=5.599999999999998
# Computing (@loadOrCompute): Datos/Results/Results_test2\results_5.65.txt
# Balancing for we=5.649999999999998
# Computing (@loadOrCompute): Datos/Results/Results_test2\results_5.7.txt
# Balancing for we=5.6999999999999975
# Computing (@loadOrCompute): Datos/Results/Results_test2\results_5.75.txt
# Balancing for we=5.749999999999997
# Computing (@loadOrCompute): Datos/Results/Results_test2\results_5.8.txt
# Balancing for we=5.799999999999997
# Computing (@loadOrCompute): Datos/Results/Results_test2\results_5.85.txt
# Balancing for we=5.849999999999997
# Computing (@loadOrCompute): Datos/Results/Results_test2\results_5.9.txt
# Balancing for we=5.899999999999997
# Computing (@loadOrCompute): Datos/Results/Results_test2\results_5.95.txt
# Balancing for we=5.949999999999997
# Computing (@loadOrCompute): Datos/Results/Results_test2\results_6.0.txt
# Balancing for we=5.9999999999999964
#
# Processing: 5.05  Loading file (@loadOrCompute): Datos/Results/Results_test2\results_5.05.txt !!!
# maxRateFIC => 25.213700677983745
#
# Processing: 5.1  Loading file (@loadOrCompute): Datos/Results/Results_test2\results_5.1.txt !!!
# maxRateFIC => 26.301317403727655
#
# Processing: 5.1499999999999995  Loading file (@loadOrCompute): Datos/Results/Results_test2\results_5.15.txt !!!
# maxRateFIC => 22.560709423878933
#
# Processing: 5.199999999999999  Loading file (@loadOrCompute): Datos/Results/Results_test2\results_5.2.txt !!!
# maxRateFIC => 18.77251634849777
#
# Processing: 5.249999999999999  Loading file (@loadOrCompute): Datos/Results/Results_test2\results_5.25.txt !!!
# Exception ignored on calling ctypes callback function: <function ExecutionEngine._raw_object_cache_notify at 0x000001D1CEAF9580>
# Traceback (most recent call last):
#   File "C:\Users\Facundo\AppData\Local\Programs\Python\Python311\Lib\site-packages\llvmlite\binding\executionengine.py", line 171, in _raw_object_cache_notify
#     def _raw_object_cache_notify(self, data):
#
# KeyboardInterrupt:
# maxRateFIC => 27.10691301801289
#
# Processing: 5.299999999999999  Loading file (@loadOrCompute): Datos/Results/Results_test2\results_5.3.txt !!!
# maxRateFIC => 22.406776649373917
#
# Processing: 5.349999999999999  Loading file (@loadOrCompute): Datos/Results/Results_test2\results_5.35.txt !!!
# maxRateFIC => 27.70938048467601
#
# Processing: 5.399999999999999  Loading file (@loadOrCompute): Datos/Results/Results_test2\results_5.4.txt !!!
# maxRateFIC => 28.712403124569917
#
# Processing: 5.449999999999998  Loading file (@loadOrCompute): Datos/Results/Results_test2\results_5.45.txt !!!
# maxRateFIC => 26.530542500675654
#
# Processing: 5.499999999999998  Loading file (@loadOrCompute): Datos/Results/Results_test2\results_5.5.txt !!!
# maxRateFIC => 11.38281386461155
#
# Processing: 5.549999999999998  Loading file (@loadOrCompute): Datos/Results/Results_test2\results_5.55.txt !!!
# maxRateFIC => 31.046858359749052
#
# Processing: 5.599999999999998  Loading file (@loadOrCompute): Datos/Results/Results_test2\results_5.6.txt !!!
# maxRateFIC => 30.56372664739808
#
# Processing: 5.649999999999998  Loading file (@loadOrCompute): Datos/Results/Results_test2\results_5.65.txt !!!
# maxRateFIC => 14.266303160539865
#
# Processing: 5.6999999999999975  Loading file (@loadOrCompute): Datos/Results/Results_test2\results_5.7.txt !!!
# maxRateFIC => 21.753468475841302
#
# Processing: 5.749999999999997  Loading file (@loadOrCompute): Datos/Results/Results_test2\results_5.75.txt !!!
# maxRateFIC => 34.16532692298615
#
# Processing: 5.799999999999997  Loading file (@loadOrCompute): Datos/Results/Results_test2\results_5.8.txt !!!
# maxRateFIC => 34.55595864031266
#
# Processing: 5.849999999999997  Loading file (@loadOrCompute): Datos/Results/Results_test2\results_5.85.txt !!!
# maxRateFIC => 33.215841063166664
#
# Processing: 5.899999999999997  Loading file (@loadOrCompute): Datos/Results/Results_test2\results_5.9.txt !!!
# maxRateFIC => 34.12294318982436
#
# Processing: 5.949999999999997  Loading file (@loadOrCompute): Datos/Results/Results_test2\results_5.95.txt !!!
# maxRateFIC => 35.53566772320235
#
# Processing: 5.9999999999999964  Loading file (@loadOrCompute): Datos/Results/Results_test2\results_6.0.txt !!!
# maxRateFIC => 34.26359096116313

# %% [markdown]
# ##### 25x25

# %%
# Carpeta destino
folder_path = 'Datos/Results/Results_test'

fig_Deco_optim.plotMaxFrecForAllWe(matriz_conectividad_promedio, fileName=os.path.join(folder_path, 'results_{}.txt'), num_processes=6)
# Out:
# ======================================
# =    simulating E-E (no FIC)         =
# ======================================
# 100%|██████████| 120/120 [00:50<00:00,  2.36it/s]
# ======================================
# =    simulating FIC                  =
# ======================================
# Loading file (@loadOrCompute): Datos/Results/Results_test\results_0.05.txt !!!
# Loading file (@loadOrCompute): Datos/Results/Results_test\results_0.1.txt !!!
# Loading file (@loadOrCompute): Datos/Results/Results_test\results_0.15.txt !!!
# Loading file (@loadOrCompute): Datos/Results/Results_test\results_0.2.txt !!!
# Loading file (@loadOrCompute): Datos/Results/Results_test\results_0.25.txt !!!
# Loading file (@loadOrCompute): Datos/Results/Results_test\results_0.3.txt !!!
# Loading file (@loadOrCompute): Datos/Results/Results_test\results_0.35.txt !!!
# Loading file (@loadOrCompute): Datos/Results/Results_test\results_0.4.txt !!!
# Loading file (@loadOrCompute): Datos/Results/Results_test\results_0.45.txt !!!
# Loading file (@loadOrCompute): Datos/Results/Results_test\results_0.5.txt !!!
# Loading file (@loadOrCompute): Datos/Results/Results_test\results_0.55.txt !!!
# Loading file (@loadOrCompute): Datos/Results/Results_test\results_0.6.txt !!!
# Loading file (@loadOrCompute): Datos/Results/Results_test\results_0.65.txt !!!
# Loading file (@loadOrCompute): Datos/Results/Results_test\results_0.7.txt !!!
# Loading file (@loadOrCompute): Datos/Results/Results_test\results_0.75.txt !!!
# Loading file (@loadOrCompute): Datos/Results/Results_test\results_0.8.txt !!!
# Loading file (@loadOrCompute): Datos/Results/Results_test\results_0.85.txt !!!
# Loading file (@loadOrCompute): Datos/Results/Results_test\results_0.9.txt !!!
# Loading file (@loadOrCompute): Datos/Results/Results_test\results_0.95.txt !!!
# Loading file (@loadOrCompute): Datos/Results/Results_test\results_1.0.txt !!!
# Loading file (@loadOrCompute): Datos/Results/Results_test\results_1.05.txt !!!
# Loading file (@loadOrCompute): Datos/Results/Results_test\results_1.1.txt !!!
# Loading file (@loadOrCompute): Datos/Results/Results_test\results_1.15.txt !!!
# Loading file (@loadOrCompute): Datos/Results/Results_test\results_1.2.txt !!!
# Loading file (@loadOrCompute): Datos/Results/Results_test\results_1.25.txt !!!
# Loading file (@loadOrCompute): Datos/Results/Results_test\results_1.3.txt !!!
# Loading file (@loadOrCompute): Datos/Results/Results_test\results_1.35.txt !!!
# Loading file (@loadOrCompute): Datos/Results/Results_test\results_1.4.txt !!!
# Loading file (@loadOrCompute): Datos/Results/Results_test\results_1.45.txt !!!
# Loading file (@loadOrCompute): Datos/Results/Results_test\results_1.5.txt !!!
# Loading file (@loadOrCompute): Datos/Results/Results_test\results_1.55.txt !!!
# Loading file (@loadOrCompute): Datos/Results/Results_test\results_1.6.txt !!!
# Loading file (@loadOrCompute): Datos/Results/Results_test\results_1.65.txt !!!
# Loading file (@loadOrCompute): Datos/Results/Results_test\results_1.7.txt !!!
# Loading file (@loadOrCompute): Datos/Results/Results_test\results_1.75.txt !!!
# Loading file (@loadOrCompute): Datos/Results/Results_test\results_1.8.txt !!!
# Loading file (@loadOrCompute): Datos/Results/Results_test\results_1.85.txt !!!
# Loading file (@loadOrCompute): Datos/Results/Results_test\results_1.9.txt !!!
# Loading file (@loadOrCompute): Datos/Results/Results_test\results_1.95.txt !!!
# Loading file (@loadOrCompute): Datos/Results/Results_test\results_2.0.txt !!!
# Loading file (@loadOrCompute): Datos/Results/Results_test\results_2.05.txt !!!
# Loading file (@loadOrCompute): Datos/Results/Results_test\results_2.1.txt !!!
# Loading file (@loadOrCompute): Datos/Results/Results_test\results_2.15.txt !!!
# Loading file (@loadOrCompute): Datos/Results/Results_test\results_2.2.txt !!!
# Loading file (@loadOrCompute): Datos/Results/Results_test\results_2.25.txt !!!
# Loading file (@loadOrCompute): Datos/Results/Results_test\results_2.3.txt !!!
# Loading file (@loadOrCompute): Datos/Results/Results_test\results_2.35.txt !!!
# Loading file (@loadOrCompute): Datos/Results/Results_test\results_2.4.txt !!!
# Loading file (@loadOrCompute): Datos/Results/Results_test\results_2.45.txt !!!
# Loading file (@loadOrCompute): Datos/Results/Results_test\results_2.5.txt !!!
# Loading file (@loadOrCompute): Datos/Results/Results_test\results_2.55.txt !!!
# Loading file (@loadOrCompute): Datos/Results/Results_test\results_2.6.txt !!!
# Loading file (@loadOrCompute): Datos/Results/Results_test\results_2.65.txt !!!
# Loading file (@loadOrCompute): Datos/Results/Results_test\results_2.7.txt !!!
# Loading file (@loadOrCompute): Datos/Results/Results_test\results_2.75.txt !!!
# Loading file (@loadOrCompute): Datos/Results/Results_test\results_2.8.txt !!!
# Loading file (@loadOrCompute): Datos/Results/Results_test\results_2.85.txt !!!
# Loading file (@loadOrCompute): Datos/Results/Results_test\results_2.9.txt !!!
# Loading file (@loadOrCompute): Datos/Results/Results_test\results_2.95.txt !!!
# Loading file (@loadOrCompute): Datos/Results/Results_test\results_3.0.txt !!!
# Loading file (@loadOrCompute): Datos/Results/Results_test\results_3.05.txt !!!
# Loading file (@loadOrCompute): Datos/Results/Results_test\results_3.1.txt !!!
# Loading file (@loadOrCompute): Datos/Results/Results_test\results_3.15.txt !!!
# Loading file (@loadOrCompute): Datos/Results/Results_test\results_3.2.txt !!!
# Loading file (@loadOrCompute): Datos/Results/Results_test\results_3.25.txt !!!
# Loading file (@loadOrCompute): Datos/Results/Results_test\results_3.3.txt !!!
# Loading file (@loadOrCompute): Datos/Results/Results_test\results_3.35.txt !!!
# Loading file (@loadOrCompute): Datos/Results/Results_test\results_3.4.txt !!!
# Loading file (@loadOrCompute): Datos/Results/Results_test\results_3.45.txt !!!
# Loading file (@loadOrCompute): Datos/Results/Results_test\results_3.5.txt !!!
# Loading file (@loadOrCompute): Datos/Results/Results_test\results_3.55.txt !!!
# Loading file (@loadOrCompute): Datos/Results/Results_test\results_3.6.txt !!!
# Loading file (@loadOrCompute): Datos/Results/Results_test\results_3.65.txt !!!
# Loading file (@loadOrCompute): Datos/Results/Results_test\results_3.7.txt !!!
# Loading file (@loadOrCompute): Datos/Results/Results_test\results_3.75.txt !!!
# Loading file (@loadOrCompute): Datos/Results/Results_test\results_3.8.txt !!!
# Loading file (@loadOrCompute): Datos/Results/Results_test\results_3.85.txt !!!
# Loading file (@loadOrCompute): Datos/Results/Results_test\results_3.9.txt !!!
# Loading file (@loadOrCompute): Datos/Results/Results_test\results_3.95.txt !!!
# Loading file (@loadOrCompute): Datos/Results/Results_test\results_4.0.txt !!!
# Loading file (@loadOrCompute): Datos/Results/Results_test\results_4.05.txt !!!
# Loading file (@loadOrCompute): Datos/Results/Results_test\results_4.1.txt !!!
# Loading file (@loadOrCompute): Datos/Results/Results_test\results_4.15.txt !!!
# Loading file (@loadOrCompute): Datos/Results/Results_test\results_4.2.txt !!!
# Loading file (@loadOrCompute): Datos/Results/Results_test\results_4.25.txt !!!
# Loading file (@loadOrCompute): Datos/Results/Results_test\results_4.3.txt !!!
# Loading file (@loadOrCompute): Datos/Results/Results_test\results_4.35.txt !!!
# Loading file (@loadOrCompute): Datos/Results/Results_test\results_4.4.txt !!!
# Loading file (@loadOrCompute): Datos/Results/Results_test\results_4.45.txt !!!
# Loading file (@loadOrCompute): Datos/Results/Results_test\results_4.5.txt !!!
# Loading file (@loadOrCompute): Datos/Results/Results_test\results_4.55.txt !!!
# Loading file (@loadOrCompute): Datos/Results/Results_test\results_4.6.txt !!!
# Loading file (@loadOrCompute): Datos/Results/Results_test\results_4.65.txt !!!
# Loading file (@loadOrCompute): Datos/Results/Results_test\results_4.7.txt !!!
# Loading file (@loadOrCompute): Datos/Results/Results_test\results_4.75.txt !!!
# Loading file (@loadOrCompute): Datos/Results/Results_test\results_4.8.txt !!!
# Loading file (@loadOrCompute): Datos/Results/Results_test\results_4.85.txt !!!
# Loading file (@loadOrCompute): Datos/Results/Results_test\results_4.9.txt !!!
# Loading file (@loadOrCompute): Datos/Results/Results_test\results_4.95.txt !!!
# Loading file (@loadOrCompute): Datos/Results/Results_test\results_5.0.txt !!!
# Loading file (@loadOrCompute): Datos/Results/Results_test\results_5.05.txt !!!
# Loading file (@loadOrCompute): Datos/Results/Results_test\results_5.1.txt !!!
# Loading file (@loadOrCompute): Datos/Results/Results_test\results_5.15.txt !!!
# Loading file (@loadOrCompute): Datos/Results/Results_test\results_5.2.txt !!!
# Loading file (@loadOrCompute): Datos/Results/Results_test\results_5.25.txt !!!
# Loading file (@loadOrCompute): Datos/Results/Results_test\results_5.3.txt !!!
# Loading file (@loadOrCompute): Datos/Results/Results_test\results_5.35.txt !!!
# Loading file (@loadOrCompute): Datos/Results/Results_test\results_5.4.txt !!!
# Loading file (@loadOrCompute): Datos/Results/Results_test\results_5.45.txt !!!
# Loading file (@loadOrCompute): Datos/Results/Results_test\results_5.5.txt !!!
# Loading file (@loadOrCompute): Datos/Results/Results_test\results_5.55.txt !!!
# Loading file (@loadOrCompute): Datos/Results/Results_test\results_5.6.txt !!!
# Loading file (@loadOrCompute): Datos/Results/Results_test\results_5.65.txt !!!
# Loading file (@loadOrCompute): Datos/Results/Results_test\results_5.7.txt !!!
# Loading file (@loadOrCompute): Datos/Results/Results_test\results_5.75.txt !!!
# Loading file (@loadOrCompute): Datos/Results/Results_test\results_5.8.txt !!!
# Loading file (@loadOrCompute): Datos/Results/Results_test\results_5.85.txt !!!
# Loading file (@loadOrCompute): Datos/Results/Results_test\results_5.9.txt !!!
# Loading file (@loadOrCompute): Datos/Results/Results_test\results_5.95.txt !!!
# Loading file (@loadOrCompute): Datos/Results/Results_test\results_6.0.txt !!!
#
# Processing: 0.05  Loading file (@loadOrCompute): Datos/Results/Results_test\results_0.05.txt !!!
# maxRateFIC => 3.7555499310106506
#
# Processing: 0.1  Loading file (@loadOrCompute): Datos/Results/Results_test\results_0.1.txt !!!
# maxRateFIC => 3.8777547219554145
#
# Processing: 0.15000000000000002  Loading file (@loadOrCompute): Datos/Results/Results_test\results_0.15.txt !!!
# maxRateFIC => 3.6224644030907394
#
# Processing: 0.2  Loading file (@loadOrCompute): Datos/Results/Results_test\results_0.2.txt !!!
# maxRateFIC => 4.100612355718255
#
# Processing: 0.25  Loading file (@loadOrCompute): Datos/Results/Results_test\results_0.25.txt !!!
# maxRateFIC => 3.656812418167396
#
# Processing: 0.3  Loading file (@loadOrCompute): Datos/Results/Results_test\results_0.3.txt !!!
# maxRateFIC => 3.8261977529129223
#
# Processing: 0.35000000000000003  Loading file (@loadOrCompute): Datos/Results/Results_test\results_0.35.txt !!!
# maxRateFIC => 3.7101257255851126
#
# Processing: 0.4  Loading file (@loadOrCompute): Datos/Results/Results_test\results_0.4.txt !!!
# maxRateFIC => 3.7199235585708093
#
# Processing: 0.45  Loading file (@loadOrCompute): Datos/Results/Results_test\results_0.45.txt !!!
# maxRateFIC => 3.828729175555617
#
# Processing: 0.5  Loading file (@loadOrCompute): Datos/Results/Results_test\results_0.5.txt !!!
# maxRateFIC => 3.8869542527711127
#
# Processing: 0.55  Loading file (@loadOrCompute): Datos/Results/Results_test\results_0.55.txt !!!
# maxRateFIC => 3.661004846458161
#
# Processing: 0.6000000000000001  Loading file (@loadOrCompute): Datos/Results/Results_test\results_0.6.txt !!!
# maxRateFIC => 3.903965153448534
#
# Processing: 0.6500000000000001  Loading file (@loadOrCompute): Datos/Results/Results_test\results_0.65.txt !!!
# maxRateFIC => 4.145927968637723
#
# Processing: 0.7000000000000001  Loading file (@loadOrCompute): Datos/Results/Results_test\results_0.7.txt !!!
# maxRateFIC => 3.912504353925027
#
# Processing: 0.7500000000000001  Loading file (@loadOrCompute): Datos/Results/Results_test\results_0.75.txt !!!
# maxRateFIC => 4.150222844437025
#
# Processing: 0.8  Loading file (@loadOrCompute): Datos/Results/Results_test\results_0.8.txt !!!
# maxRateFIC => 4.057383180100682
#
# Processing: 0.8500000000000001  Loading file (@loadOrCompute): Datos/Results/Results_test\results_0.85.txt !!!
# maxRateFIC => 4.178234827644133
#
# Processing: 0.9000000000000001  Loading file (@loadOrCompute): Datos/Results/Results_test\results_0.9.txt !!!
# maxRateFIC => 3.804392847221637
#
# Processing: 0.9500000000000001  Loading file (@loadOrCompute): Datos/Results/Results_test\results_0.95.txt !!!
# maxRateFIC => 3.9287461730160835
#
# Processing: 1.0  Loading file (@loadOrCompute): Datos/Results/Results_test\results_1.0.txt !!!
# maxRateFIC => 3.8086615221084608
#
# Processing: 1.05  Loading file (@loadOrCompute): Datos/Results/Results_test\results_1.05.txt !!!
# maxRateFIC => 3.8052965058881965
#
# Processing: 1.1  Loading file (@loadOrCompute): Datos/Results/Results_test\results_1.1.txt !!!
# maxRateFIC => 3.9628563208667185
#
# Processing: 1.1500000000000001  Loading file (@loadOrCompute): Datos/Results/Results_test\results_1.15.txt !!!
# maxRateFIC => 3.9830701697419597
#
# Processing: 1.2000000000000002  Loading file (@loadOrCompute): Datos/Results/Results_test\results_1.2.txt !!!
# maxRateFIC => 3.786796686724475
#
# Processing: 1.2500000000000002  Loading file (@loadOrCompute): Datos/Results/Results_test\results_1.25.txt !!!
# maxRateFIC => 3.952806574631777
#
# Processing: 1.3  Loading file (@loadOrCompute): Datos/Results/Results_test\results_1.3.txt !!!
# maxRateFIC => 3.942531133734899
#
# Processing: 1.35  Loading file (@loadOrCompute): Datos/Results/Results_test\results_1.35.txt !!!
# maxRateFIC => 3.869751596453518
#
# Processing: 1.4000000000000001  Loading file (@loadOrCompute): Datos/Results/Results_test\results_1.4.txt !!!
# maxRateFIC => 3.9030386245461504
#
# Processing: 1.4500000000000002  Loading file (@loadOrCompute): Datos/Results/Results_test\results_1.45.txt !!!
# maxRateFIC => 4.018419789781703
#
# Processing: 1.5000000000000002  Loading file (@loadOrCompute): Datos/Results/Results_test\results_1.5.txt !!!
# maxRateFIC => 3.883114937492813
#
# Processing: 1.55  Loading file (@loadOrCompute): Datos/Results/Results_test\results_1.55.txt !!!
# maxRateFIC => 4.040727519731542
#
# Processing: 1.6  Loading file (@loadOrCompute): Datos/Results/Results_test\results_1.6.txt !!!
# maxRateFIC => 3.8889624430483836
#
# Processing: 1.6500000000000001  Loading file (@loadOrCompute): Datos/Results/Results_test\results_1.65.txt !!!
# maxRateFIC => 4.083945537976563
#
# Processing: 1.7000000000000002  Loading file (@loadOrCompute): Datos/Results/Results_test\results_1.7.txt !!!
# maxRateFIC => 3.9001207906475255
#
# Processing: 1.7500000000000002  Loading file (@loadOrCompute): Datos/Results/Results_test\results_1.75.txt !!!
# maxRateFIC => 3.671010361588355
#
# Processing: 1.8  Loading file (@loadOrCompute): Datos/Results/Results_test\results_1.8.txt !!!
# maxRateFIC => 3.712312825995962
#
# Processing: 1.85  Loading file (@loadOrCompute): Datos/Results/Results_test\results_1.85.txt !!!
# maxRateFIC => 4.062577636424047
#
# Processing: 1.9000000000000001  Loading file (@loadOrCompute): Datos/Results/Results_test\results_1.9.txt !!!
# maxRateFIC => 3.956099555306258
#
# Processing: 1.9500000000000002  Loading file (@loadOrCompute): Datos/Results/Results_test\results_1.95.txt !!!
# maxRateFIC => 4.03928577211065
#
# Processing: 2.0  Loading file (@loadOrCompute): Datos/Results/Results_test\results_2.0.txt !!!
# maxRateFIC => 4.03850815075609
#
# Processing: 2.05  Loading file (@loadOrCompute): Datos/Results/Results_test\results_2.05.txt !!!
# maxRateFIC => 3.915305917229288
#
# Processing: 2.1  Loading file (@loadOrCompute): Datos/Results/Results_test\results_2.1.txt !!!
# maxRateFIC => 4.135349655758464
#
# Processing: 2.15  Loading file (@loadOrCompute): Datos/Results/Results_test\results_2.15.txt !!!
# maxRateFIC => 3.8436437001510617
#
# Processing: 2.1999999999999997  Loading file (@loadOrCompute): Datos/Results/Results_test\results_2.2.txt !!!
# maxRateFIC => 4.713577870716918
#
# Processing: 2.25  Loading file (@loadOrCompute): Datos/Results/Results_test\results_2.25.txt !!!
# maxRateFIC => 3.9434970845324453
#
# Processing: 2.3  Loading file (@loadOrCompute): Datos/Results/Results_test\results_2.3.txt !!!
# maxRateFIC => 4.425062793532505
#
# Processing: 2.35  Loading file (@loadOrCompute): Datos/Results/Results_test\results_2.35.txt !!!
# maxRateFIC => 3.7706301972404184
#
# Processing: 2.4  Loading file (@loadOrCompute): Datos/Results/Results_test\results_2.4.txt !!!
# maxRateFIC => 4.169900053490635
#
# Processing: 2.45  Loading file (@loadOrCompute): Datos/Results/Results_test\results_2.45.txt !!!
# maxRateFIC => 4.1937990600740385
#
# Processing: 2.5  Loading file (@loadOrCompute): Datos/Results/Results_test\results_2.5.txt !!!
# maxRateFIC => 4.302009664839512
#
# Processing: 2.55  Loading file (@loadOrCompute): Datos/Results/Results_test\results_2.55.txt !!!
# maxRateFIC => 5.49955837015152
#
# Processing: 2.6  Loading file (@loadOrCompute): Datos/Results/Results_test\results_2.6.txt !!!
# maxRateFIC => 4.256027049055525
#
# Processing: 2.65  Loading file (@loadOrCompute): Datos/Results/Results_test\results_2.65.txt !!!
# maxRateFIC => 3.8982931017192866
#
# Processing: 2.7  Loading file (@loadOrCompute): Datos/Results/Results_test\results_2.7.txt !!!
# maxRateFIC => 4.711565652538715
#
# Processing: 2.75  Loading file (@loadOrCompute): Datos/Results/Results_test\results_2.75.txt !!!
# maxRateFIC => 4.227833855853147
#
# Processing: 2.8  Loading file (@loadOrCompute): Datos/Results/Results_test\results_2.8.txt !!!
# maxRateFIC => 4.026010264926387
#
# Processing: 2.85  Loading file (@loadOrCompute): Datos/Results/Results_test\results_2.85.txt !!!
# maxRateFIC => 3.809726696850529
#
# Processing: 2.9  Loading file (@loadOrCompute): Datos/Results/Results_test\results_2.9.txt !!!
# maxRateFIC => 3.822850641494841
#
# Processing: 2.95  Loading file (@loadOrCompute): Datos/Results/Results_test\results_2.95.txt !!!
# maxRateFIC => 4.25569308045374
#
# Processing: 3.0  Loading file (@loadOrCompute): Datos/Results/Results_test\results_3.0.txt !!!
# maxRateFIC => 3.7631331175103386
#
# Processing: 3.05  Loading file (@loadOrCompute): Datos/Results/Results_test\results_3.05.txt !!!
# maxRateFIC => 4.351881244483621
#
# Processing: 3.1  Loading file (@loadOrCompute): Datos/Results/Results_test\results_3.1.txt !!!
# maxRateFIC => 4.0577272734582435
#
# Processing: 3.15  Loading file (@loadOrCompute): Datos/Results/Results_test\results_3.15.txt !!!
# maxRateFIC => 5.125337621313125
#
# Processing: 3.2  Loading file (@loadOrCompute): Datos/Results/Results_test\results_3.2.txt !!!
# maxRateFIC => 3.9650457527281784
#
# Processing: 3.25  Loading file (@loadOrCompute): Datos/Results/Results_test\results_3.25.txt !!!
# maxRateFIC => 4.865179678057057
#
# Processing: 3.3  Loading file (@loadOrCompute): Datos/Results/Results_test\results_3.3.txt !!!
# maxRateFIC => 4.408401736031296
#
# Processing: 3.35  Loading file (@loadOrCompute): Datos/Results/Results_test\results_3.35.txt !!!
# maxRateFIC => 4.148504137654064
#
# Processing: 3.4  Loading file (@loadOrCompute): Datos/Results/Results_test\results_3.4.txt !!!
# maxRateFIC => 5.779571882252174
#
# Processing: 3.45  Loading file (@loadOrCompute): Datos/Results/Results_test\results_3.45.txt !!!
# maxRateFIC => 4.218503965914298
#
# Processing: 3.5  Loading file (@loadOrCompute): Datos/Results/Results_test\results_3.5.txt !!!
# maxRateFIC => 4.272731964279043
#
# Processing: 3.55  Loading file (@loadOrCompute): Datos/Results/Results_test\results_3.55.txt !!!
# maxRateFIC => 4.156610404633893
#
# Processing: 3.6  Loading file (@loadOrCompute): Datos/Results/Results_test\results_3.6.txt !!!
# maxRateFIC => 3.9116118404424536
#
# Processing: 3.65  Loading file (@loadOrCompute): Datos/Results/Results_test\results_3.65.txt !!!
# maxRateFIC => 3.829447820199535
#
# Processing: 3.7  Loading file (@loadOrCompute): Datos/Results/Results_test\results_3.7.txt !!!
# maxRateFIC => 4.383882606544621
#
# Processing: 3.75  Loading file (@loadOrCompute): Datos/Results/Results_test\results_3.75.txt !!!
# maxRateFIC => 4.961747982017653
#
# Processing: 3.8  Loading file (@loadOrCompute): Datos/Results/Results_test\results_3.8.txt !!!
# maxRateFIC => 4.096892045562413
#
# Processing: 3.85  Loading file (@loadOrCompute): Datos/Results/Results_test\results_3.85.txt !!!
# maxRateFIC => 3.8637662512017736
#
# Processing: 3.9  Loading file (@loadOrCompute): Datos/Results/Results_test\results_3.9.txt !!!
# maxRateFIC => 4.079467327789896
#
# Processing: 3.95  Loading file (@loadOrCompute): Datos/Results/Results_test\results_3.95.txt !!!
# maxRateFIC => 4.469463328071619
#
# Processing: 4.0  Loading file (@loadOrCompute): Datos/Results/Results_test\results_4.0.txt !!!
# maxRateFIC => 4.153314741493727
#
# Processing: 4.05  Loading file (@loadOrCompute): Datos/Results/Results_test\results_4.05.txt !!!
# maxRateFIC => 4.305279900658816
#
# Processing: 4.1  Loading file (@loadOrCompute): Datos/Results/Results_test\results_4.1.txt !!!
# maxRateFIC => 4.173977818577144
#
# Processing: 4.15  Loading file (@loadOrCompute): Datos/Results/Results_test\results_4.15.txt !!!
# maxRateFIC => 4.05091622076629
#
# Processing: 4.2  Loading file (@loadOrCompute): Datos/Results/Results_test\results_4.2.txt !!!
# maxRateFIC => 4.146038251520363
#
# Processing: 4.25  Loading file (@loadOrCompute): Datos/Results/Results_test\results_4.25.txt !!!
# maxRateFIC => 4.062842226515049
#
# Processing: 4.3  Loading file (@loadOrCompute): Datos/Results/Results_test\results_4.3.txt !!!
# maxRateFIC => 4.200234011421866
#
# Processing: 4.35  Loading file (@loadOrCompute): Datos/Results/Results_test\results_4.35.txt !!!
# maxRateFIC => 4.530904365328821
#
# Processing: 4.4  Loading file (@loadOrCompute): Datos/Results/Results_test\results_4.4.txt !!!
# maxRateFIC => 5.714773231756477
#
# Processing: 4.45  Loading file (@loadOrCompute): Datos/Results/Results_test\results_4.45.txt !!!
# maxRateFIC => 9.782931959727977
#
# Processing: 4.5  Loading file (@loadOrCompute): Datos/Results/Results_test\results_4.5.txt !!!
# maxRateFIC => 4.695556774266861
#
# Processing: 4.55  Loading file (@loadOrCompute): Datos/Results/Results_test\results_4.55.txt !!!
# maxRateFIC => 5.20836922868185
#
# Processing: 4.6  Loading file (@loadOrCompute): Datos/Results/Results_test\results_4.6.txt !!!
# maxRateFIC => 4.015333757968051
#
# Processing: 4.65  Loading file (@loadOrCompute): Datos/Results/Results_test\results_4.65.txt !!!
# maxRateFIC => 4.439402646433144
#
# Processing: 4.7  Loading file (@loadOrCompute): Datos/Results/Results_test\results_4.7.txt !!!
# maxRateFIC => 4.541908980627706
#
# Processing: 4.75  Loading file (@loadOrCompute): Datos/Results/Results_test\results_4.75.txt !!!
# maxRateFIC => 4.7000695971300175
#
# Processing: 4.8  Loading file (@loadOrCompute): Datos/Results/Results_test\results_4.8.txt !!!
# maxRateFIC => 4.739853771776841
#
# Processing: 4.8500000000000005  Loading file (@loadOrCompute): Datos/Results/Results_test\results_4.85.txt !!!
# maxRateFIC => 4.672765923889454
#
# Processing: 4.9  Loading file (@loadOrCompute): Datos/Results/Results_test\results_4.9.txt !!!
# maxRateFIC => 5.420395744411188
#
# Processing: 4.95  Loading file (@loadOrCompute): Datos/Results/Results_test\results_4.95.txt !!!
# maxRateFIC => 4.558911145545234
#
# Processing: 5.0  Loading file (@loadOrCompute): Datos/Results/Results_test\results_5.0.txt !!!
# maxRateFIC => 4.78452447422725
#
# Processing: 5.05  Loading file (@loadOrCompute): Datos/Results/Results_test\results_5.05.txt !!!
# maxRateFIC => 6.012716599971042
#
# Processing: 5.1000000000000005  Loading file (@loadOrCompute): Datos/Results/Results_test\results_5.1.txt !!!
# maxRateFIC => 10.004771923770083
#
# Processing: 5.15  Loading file (@loadOrCompute): Datos/Results/Results_test\results_5.15.txt !!!
# maxRateFIC => 8.483380993841138
#
# Processing: 5.2  Loading file (@loadOrCompute): Datos/Results/Results_test\results_5.2.txt !!!
# maxRateFIC => 4.990214293739064
#
# Processing: 5.25  Loading file (@loadOrCompute): Datos/Results/Results_test\results_5.25.txt !!!
# maxRateFIC => 9.360896057848842
#
# Processing: 5.3  Loading file (@loadOrCompute): Datos/Results/Results_test\results_5.3.txt !!!
# maxRateFIC => 10.306243335178529
#
# Processing: 5.3500000000000005  Loading file (@loadOrCompute): Datos/Results/Results_test\results_5.35.txt !!!
# maxRateFIC => 6.895414754064687
#
# Processing: 5.4  Loading file (@loadOrCompute): Datos/Results/Results_test\results_5.4.txt !!!
# maxRateFIC => 7.363858589735622
#
# Processing: 5.45  Loading file (@loadOrCompute): Datos/Results/Results_test\results_5.45.txt !!!
# maxRateFIC => 7.973342934717644
#
# Processing: 5.5  Loading file (@loadOrCompute): Datos/Results/Results_test\results_5.5.txt !!!
# maxRateFIC => 6.389968248850689
#
# Processing: 5.55  Loading file (@loadOrCompute): Datos/Results/Results_test\results_5.55.txt !!!
# maxRateFIC => 5.897102923902516
#
# Processing: 5.6000000000000005  Loading file (@loadOrCompute): Datos/Results/Results_test\results_5.6.txt !!!
# maxRateFIC => 17.28499013037689
#
# Processing: 5.65  Loading file (@loadOrCompute): Datos/Results/Results_test\results_5.65.txt !!!
# maxRateFIC => 30.591279179355702
#
# Processing: 5.7  Loading file (@loadOrCompute): Datos/Results/Results_test\results_5.7.txt !!!
# maxRateFIC => 18.833264428598138
#
# Processing: 5.75  Loading file (@loadOrCompute): Datos/Results/Results_test\results_5.75.txt !!!
# maxRateFIC => 33.97822492440576
#
# Processing: 5.8  Loading file (@loadOrCompute): Datos/Results/Results_test\results_5.8.txt !!!
# maxRateFIC => 33.46463631764563
#
# Processing: 5.8500000000000005  Loading file (@loadOrCompute): Datos/Results/Results_test\results_5.85.txt !!!
# maxRateFIC => 34.62686636724126
#
# Processing: 5.9  Loading file (@loadOrCompute): Datos/Results/Results_test\results_5.9.txt !!!
# maxRateFIC => 29.487735578154954
#
# Processing: 5.95  Loading file (@loadOrCompute): Datos/Results/Results_test\results_5.95.txt !!!
# maxRateFIC => 36.98503137379067
#
# Processing: 6.0  Loading file (@loadOrCompute): Datos/Results/Results_test\results_6.0.txt !!!
# maxRateFIC => 34.75623483659823

# %% [markdown]
# ##### 200x200

# %%
# Carpeta destino
folder_path = 'Datos/Results/Results_200x200'

fig_Deco_optim.plotMaxFrecForAllWe(matriz_conectividad_promedio, fileName=os.path.join(folder_path, 'results_{}.txt'), num_processes=6)

# %% [markdown]
# #### Herzog

# %%
# Carpeta destino
outFilePath = 'Datos/Results/Results_Herzog'
fig_Herzog.outFilePath = outFilePath

wStart = 0
wStep = 0.5
wEnd = 2 + 0.001
wes = np.arange(wStart + wStep, wEnd, wStep)

fig_Herzog.C = matriz_conectividad_promedio
fig_Herzog.fileNameHerzog2022 = outFilePath + '/Human_66/Herzog_Benji_Human66_{}.mat'
fig_Herzog.fileNameDeco2014 = outFilePath + '/Human_66/Benji_Human66_{}.mat'
fig_m2, ax = plt.subplots()
fig_Herzog.plotMaxFrecForAllWe(ax, matriz_conectividad_promedio ,wes)
